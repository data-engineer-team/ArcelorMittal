# %%
import pandas as pd
import sqlite3
import csv

# %%
df= pd.read_csv('CoilDataInput.csv')
df.dtypes
# Out:
# coil                                   int64
# furnace Number                         int64
# analyse                               object
# Hardness_1                             int64
# Hardness_2                             int64
# Width                                float64
# Temperature before finishing mill    float64
# Temperature after finishing mill     float64
# Thickness                            float64
# Thickness profile                    float64
# C                                      int64
# Mn                                     int64
# Si                                     int64
# Nb                                     int64
# P                                      int64
# S                                      int64
# Al                                     int64
# M_Al                                   int64
# B                                      int64
# N                                      int64
# Ti                                     int64
# ...

# %%
df
# Out:
#          coil  furnace Number analyse  Hardness_1  Hardness_2        Width  \
# 0      283642               4    L651       12157         122  1731.316667
# 1      283643               1    KN71       11888         124  1602.800000
# 2      283644               4    KM81       12419         129  1637.133333
# 3      283645               1    KM31       11106         116  1697.450000
# 4      283646               4    KM31       11106         116  1693.975000
# ...       ...             ...     ...         ...         ...          ...
# 25298  350538               1    LM41       13043         136   766.033333
# 25299  350539               4    KM41       11473         120   821.300000
# 25300  350540               1    KM81       12368         129   775.950000
# 25301  350541               1    LM41       13027         136   769.300000
# 25302  350894               4    LK41       13032         136  1486.016667
#
# ...

# %%
df['analyse'] = df['analyse'].astype(pd.StringDtype())

# %%
df.dtypes
# Out:
# coil                                   int64
# furnace Number                         int64
# analyse                               string
# Hardness_1                             int64
# Hardness_2                             int64
# Width                                float64
# Temperature before finishing mill    float64
# Temperature after finishing mill     float64
# Thickness                            float64
# Thickness profile                    float64
# C                                      int64
# Mn                                     int64
# Si                                     int64
# Nb                                     int64
# P                                      int64
# S                                      int64
# Al                                     int64
# M_Al                                   int64
# B                                      int64
# N                                      int64
# Ti                                     int64
# ...

# %%
df.to_csv('coilDataInput1.csv', index=False)
